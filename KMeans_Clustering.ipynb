# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('OnlineRetail.csv', encoding = 'unicode_escape')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.tail(5)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
currentDate = pd.to_datetime("2012-01-01")

df['InvoiceDate']=pd.to_datetime(df["InvoiceDate"])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
currentDate
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
maxdate = df.groupby(["CustomerID"]).max()[['InvoiceDate']]
maxdate
# Out:
#                    InvoiceDate
# CustomerID
# 12346.0    2011-01-18 10:17:00
# 12347.0    2011-12-07 15:52:00
# 12348.0    2011-09-25 13:13:00
# 12349.0    2011-11-21 09:51:00
# 12350.0    2011-02-02 16:01:00
# ...                        ...
# 18280.0    2011-03-07 09:52:00
# 18281.0    2011-06-12 10:53:00
# 18282.0    2011-12-02 11:43:00
# 18283.0    2011-12-06 12:02:00
# 18287.0    2011-10-28 09:29:00
#
# [4372 rows x 1 columns]

# %%
(currentDate - maxdate['InvoiceDate']).dt.days
# Out:
# CustomerID
# 12346.0    347
# 12347.0     24
# 12348.0     97
# 12349.0     40
# 12350.0    332
#           ...
# 18280.0    299
# 18281.0    202
# 18282.0     29
# 18283.0     25
# 18287.0     64
# Name: InvoiceDate, Length: 4372, dtype: int64

# %%
maxdate['InvoiceAge'] = (currentDate - maxdate['InvoiceDate']).dt.days
maxdate
# Out:
#                    InvoiceDate  InvoiceAge
# CustomerID
# 12346.0    2011-01-18 10:17:00         347
# 12347.0    2011-12-07 15:52:00          24
# 12348.0    2011-09-25 13:13:00          97
# 12349.0    2011-11-21 09:51:00          40
# 12350.0    2011-02-02 16:01:00         332
# ...                        ...         ...
# 18280.0    2011-03-07 09:52:00         299
# 18281.0    2011-06-12 10:53:00         202
# 18282.0    2011-12-02 11:43:00          29
# 18283.0    2011-12-06 12:02:00          25
# 18287.0    2011-10-28 09:29:00          64
#
# [4372 rows x 2 columns]

# %%
#recenccy

recency = maxdate.drop('InvoiceDate', axis=1)
recency
# Out:
#             InvoiceAge
# CustomerID
# 12346.0            347
# 12347.0             24
# 12348.0             97
# 12349.0             40
# 12350.0            332
# ...                ...
# 18280.0            299
# 18281.0            202
# 18282.0             29
# 18283.0             25
# 18287.0             64
#
# [4372 rows x 1 columns]

# %%
freq = df.drop_duplicates(subset="InvoiceNo")
freq
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 21        536368     22960             JAM MAKING SET WITH JARS         6
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# ...          ...       ...                                  ...       ...
# 541865    581583     20725              LUNCH BAG RED RETROSPOT        40
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541869    581585     22481       BLACK TEA TOWEL CLASSIC DESIGN        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 7      2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9      2010-12-01 08:34:00       1.69     13047.0  United Kingdom
# 21     2010-12-01 08:34:00       4.25     13047.0  United Kingdom
# 25     2010-12-01 08:35:00       5.95     13047.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541865 2011-12-09 12:23:00       1.45     13777.0  United Kingdom
# 541867 2011-12-09 12:25:00       0.72     13777.0  United Kingdom
# 541869 2011-12-09 12:31:00       0.39     15804.0  United Kingdom
# 541890 2011-12-09 12:49:00       2.95     13113.0  United Kingdom
# 541894 2011-12-09 12:50:00       1.95     12680.0          France
#
# [25900 rows x 8 columns]

# %%
freq = freq.groupby(["CustomerID"]).count()[["InvoiceNo"]]
freq
# Out:
#             InvoiceNo
# CustomerID
# 12346.0             2
# 12347.0             7
# 12348.0             4
# 12349.0             1
# 12350.0             1
# ...               ...
# 18280.0             1
# 18281.0             1
# 18282.0             3
# 18283.0            16
# 18287.0             3
#
# [4372 rows x 1 columns]

# %%
#monetary
df["total"]=df["Quantity"]*df["UnitPrice"]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  total
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# ...                    ...        ...         ...             ...    ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France  10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France  12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France  16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France  16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France  14.85
#
# [541909 rows x 9 columns]

# %%
money=df.groupby(["CustomerID"])[["total"]].sum()
money
# Out:
#               total
# CustomerID
# 12346.0        0.00
# 12347.0     4310.00
# 12348.0     1797.24
# 12349.0     1757.55
# 12350.0      334.40
# ...             ...
# 18280.0      180.60
# 18281.0       80.82
# 18282.0      176.60
# 18283.0     2094.88
# 18287.0     1837.28
#
# [4372 rows x 1 columns]

# %%
df[df['CustomerID']==12346.0]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country    total
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom  77183.6
# 61624 2011-01-18 10:17:00       1.04     12346.0  United Kingdom -77183.6

# %%
RFM=pd.concat([recency,freq,money], axis=1)
RFM
# Out:
#             InvoiceAge  InvoiceNo    total
# CustomerID
# 12346.0            347          2     0.00
# 12347.0             24          7  4310.00
# 12348.0             97          4  1797.24
# 12349.0             40          1  1757.55
# 12350.0            332          1   334.40
# ...                ...        ...      ...
# 18280.0            299          1   180.60
# 18281.0            202          1    80.82
# 18282.0             29          3   176.60
# 18283.0             25         16  2094.88
# 18287.0             64          3  1837.28
#
# [4372 rows x 3 columns]

# %%
RFM.columns = ['Recency', 'Frequency', 'Monetary']
RFM
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         347          2      0.00
# 12347.0          24          7   4310.00
# 12348.0          97          4   1797.24
# 12349.0          40          1   1757.55
# 12350.0         332          1    334.40
# ...             ...        ...       ...
# 18280.0         299          1    180.60
# 18281.0         202          1     80.82
# 18282.0          29          3    176.60
# 18283.0          25         16   2094.88
# 18287.0          64          3   1837.28
#
# [4372 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled=scaler.fit_transform(RFM)

# %%
from sklearn.cluster import KMeans

# %%
k_range = range(2,11)
sse = []
for k in k_range:
    km = KMeans(n_clusters=k) 
    km.fit(scaled)
    sse.append(km.inertia_)

# %%
sse
# Out:
# [9134.642381209182,
#  6074.281828139152,
#  4081.896097033865,
#  3027.8804723150424,
#  2600.222268888354,
#  2006.6168011426225,
#  1585.5649930710326,
#  1397.970817541669,
#  1279.411529800625]

# %%
plt.plot(k_range, sse, 'r-*')
plt.xlabel ='k'
plt.ylabel = 'Sum of Squared Error'

# %%
# !pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in d:\anaconda\lib\site-packages (from yellowbrick) (3.10.0)
# Requirement already satisfied: scipy>=1.0.0 in d:\anaconda\lib\site-packages (from yellowbrick) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\anaconda\lib\site-packages (from yellowbrick) (1.6.1)
# Requirement already satisfied: numpy>=1.16.0 in d:\anaconda\lib\site-packages (from yellowbrick) (2.1.3)
# Requirement already satisfied: cycler>=0.10.0 in d:\anaconda\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.2)
# Requirement already satisfied: pillow>=8 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5

# %%
from yellowbrick.cluster import KElbowVisualizer
Elbow = KElbowVisualizer(KMeans(), k=10)
Elbow.fit(scaled)
Elbow.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(scaled)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans.labels_.shape
# Out:
# (4372,)

# %%
RFM["Clusters"]=(kmeans.labels_)
RFM
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12346.0         347          2      0.00         1
# 12347.0          24          7   4310.00         0
# 12348.0          97          4   1797.24         0
# 12349.0          40          1   1757.55         0
# 12350.0         332          1    334.40         1
# ...             ...        ...       ...       ...
# 18280.0         299          1    180.60         1
# 18281.0         202          1     80.82         1
# 18282.0          29          3    176.60         0
# 18283.0          25         16   2094.88         0
# 18287.0          64          3   1837.28         0
#
# [4372 rows x 4 columns]

# %%
RFM.Clusters.unique()
# Out:
# array([1, 0, 2], dtype=int32)

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.subplot(111, projection='3d', label="bla")
ax.scatter(RFM["Recency"],RFM["Frequency"],RFM["Monetary"], s=40, c=RFM["Clusters"], marker='o', cmap = "Accent")
ax.set_title("The Plot Of The Clusters")
plt.show()

# %%
RFM[RFM.Clusters==0]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12347.0          24          7   4310.00         0
# 12348.0          97          4   1797.24         0
# 12349.0          40          1   1757.55         0
# 12352.0          58         11   1545.41         0
# 12356.0          44          3   2811.43         0
# ...             ...        ...       ...       ...
# 18277.0          80          2     97.63         0
# 18278.0          95          1    173.90         0
# 18282.0          29          3    176.60         0
# 18283.0          25         16   2094.88         0
# 18287.0          64          3   1837.28         0
#
# [3247 rows x 4 columns]

# %%
RFM[RFM.Clusters==1]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12346.0         347          2      0.00         1
# 12350.0         332          1    334.40         1
# 12353.0         226          1     89.00         1
# 12354.0         254          1   1079.40         1
# 12355.0         236          1    459.40         1
# ...             ...        ...       ...       ...
# 18260.0         194          8   2595.00         1
# 18262.0         162          1    149.48         1
# 18269.0         380          2    138.90         1
# 18280.0         299          1    180.60         1
# 18281.0         202          1     80.82         1
#
# [1119 rows x 4 columns]

# %%
RFM[RFM.Clusters==2]
# Out:
#             Recency  Frequency   Monetary  Clusters
# CustomerID
# 12415.0          46         26  123725.45         2
# 14156.0          31         66  113384.14         2
# 14646.0          23         77  279489.02         2
# 14911.0          23        248  132572.62         2
# 17450.0          30         55  187482.17         2
# 18102.0          22         62  256438.49         2

# %%
final=RFM.groupby("Clusters").mean()[["Recency","Frequency","Monetary"]]
final
# Out:
#              Recency  Frequency       Monetary
# Clusters
# 0          61.019403   6.031414    2060.678643
# 1         266.552279   1.851653     461.081654
# 2          29.166667  89.000000  182181.981667

# %%
def func(row):
    if row["Clusters"]==0:
        return 'Silver'
    elif row["Clusters"]==2:
        return 'Diamond'
    else:
        return 'Gold'

# %%
RFM['group']=RFM.apply(func, axis=1)
RFM
# Out:
#             Recency  Frequency  Monetary  Clusters   group
# CustomerID
# 12346.0         347          2      0.00         1    Gold
# 12347.0          24          7   4310.00         0  Silver
# 12348.0          97          4   1797.24         0  Silver
# 12349.0          40          1   1757.55         0  Silver
# 12350.0         332          1    334.40         1    Gold
# ...             ...        ...       ...       ...     ...
# 18280.0         299          1    180.60         1    Gold
# 18281.0         202          1     80.82         1    Gold
# 18282.0          29          3    176.60         0  Silver
# 18283.0          25         16   2094.88         0  Silver
# 18287.0          64          3   1837.28         0  Silver
#
# [4372 rows x 5 columns]

# %%
result = pd.DataFrame(RFM.group.value_counts())

# %%
result = result.reset_index()
result
# Out:
#      group  count
# 0   Silver   3247
# 1     Gold   1119
# 2  Diamond      6

# %%
import seaborn as sns

# %%
datalabel=sns.barplot(x="group", y="count", data=result, estimator=np.sum)
for i in datalabel.containers:
    datalabel.bar_label(i,)

# %%
ABC = RFM[RFM.Clusters==2]

# %%
ABC[ABC['Monetary']==ABC['Monetary'].min()]
# Out:
#             Recency  Frequency   Monetary  Clusters    group
# CustomerID
# 14156.0          31         66  113384.14         2  Diamond

# %%
ABC[ABC['Monetary']==ABC['Monetary'].max()]
# Out:
#             Recency  Frequency   Monetary  Clusters    group
# CustomerID
# 14646.0          23         77  279489.02         2  Diamond

# %%
ABC = RFM[RFM.Clusters==0]
ABC[ABC['Monetary']==ABC['Monetary'].max()]
# Out:
#             Recency  Frequency  Monetary  Clusters   group
# CustomerID
# 17511.0          24         46  88125.38         0  Silver
